# %% [markdown]
# <a href="https://colab.research.google.com/github/Gulnaz-Aydemir/Python-Programming/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pi_sayisi=3.14
katsayi=2
toplam=pi_sayisi+1
fark=pi_sayisi-1
carpim=pi_sayisi * katsayi
bolum=pi_sayisi / katsayi
print("toplam:", toplam)
print("fark:", fark)
print("çarpım:", carpim)
print("bölüm:", bolum)
# Out:
# toplam: 4.140000000000001
# fark: 2.14
# çarpım: 6.28
# bölüm: 1.57

# %%
metin= 'merhaba dünya'
print(metin)
# Out:
# merhaba dünya

# %%
kelime="google"
veri_tipi=type(kelime) #type pythonda tanımlı bir metottur ve değişkenin veri tipini döndürür.
print(veri_tipi)
# Out:
# <class 'str'>

# %%
#metinleri birleştirmek için + işareti kullanılır.
sirket="google"
ayrac="--"
kurulus="1998"
birlestirilmis_metin=sirket+ayrac+kurulus
print(birlestirilmis_metin)
# Out:
# google--1998

# %%
metin_sayisi1="100"
metin_sayisi2="200"
sonuc=metin_sayisi1+metin_sayisi2
print(sonuc)
# Out:
# 100200
